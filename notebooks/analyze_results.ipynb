# %% [markdown]
# # Analyze Results

# %% [markdown]
# <!--<badge>--><a href="https://colab.research.google.com/github/thaonguyen274/employee-future-prediciton/blob/master/notebooks/analyze_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><!--</badge>-->

# %% [markdown]
# ## Load Data and Model

# %%
from yellowbrick.classifier import ClassificationReport, ConfusionMatrix, ROCAUC
import joblib 
import pandas as pd

# %%
# !pip install "black[jupyter]"
# Out:
# Requirement already satisfied: black[jupyter] in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (23.3.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from black[jupyter]) (2.0.1)
# Requirement already satisfied: pathspec>=0.9.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from black[jupyter]) (0.11.1)
# Requirement already satisfied: click>=8.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from black[jupyter]) (8.1.3)
# Requirement already satisfied: packaging>=22.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from black[jupyter]) (23.0)
# Requirement already satisfied: platformdirs>=2 in /home/ubuntu/.local/lib/python3.8/site-packages (from black[jupyter]) (3.2.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from black[jupyter]) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from black[jupyter]) (4.5.0)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from black[jupyter]) (5.0.0)
# Requirement already satisfied: ipython>=7.8.0 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from black[jupyter]) (8.12.0)
# Requirement already satisfied: traitlets>=5 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (5.9.0)
# Requirement already satisfied: pickleshare in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/ubuntu/.local/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (3.0.38)
# Requirement already satisfied: stack-data in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (0.18.2)
# Requirement already satisfied: decorator in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (5.1.1)
# Requirement already satisfied: backcall in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (2.14.0)
# Requirement already satisfied: matplotlib-inline in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from ipython>=7.8.0->black[jupyter]) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.8.0->black[jupyter]) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ubuntu/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.8.0->black[jupyter]) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from stack-data->ipython>=7.8.0->black[jupyter]) (2.2.1)
# Requirement already satisfied: pure-eval in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from stack-data->ipython>=7.8.0->black[jupyter]) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from stack-data->ipython>=7.8.0->black[jupyter]) (1.2.0)
# Requirement already satisfied: six in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from asttokens>=2.1.0->stack-data->ipython>=7.8.0->black[jupyter]) (1.16.0)

# %%
X_train = pd.read_csv('../data/processed/X_train.csv')
X_test = pd.read_csv('../data/processed/X_test.csv')
y_train = pd.read_csv('../data/processed/y_train.csv')
y_test = pd.read_csv('../data/processed/y_test.csv')

# %%
model = joblib.load('../models/xgboost')

# %% [markdown]
# ## Classification Report

# %% [markdown]
# The classification report visualizer displays the precision, recall, F1, and support scores for the model.

# %%
visualizer = ClassificationReport(model, classes=[0, 1], support=True)

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# <AxesSubplot: title={'center': 'XGBClassifier Classification Report'}>

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# What is the percentage of false predictions among those who leave in 2 years? What is the percentage of false predictions among those who stay more than 2 years? The confusion matrix helps us to answer this question

# %%
visualizer = ConfusionMatrix(model, classes=[0, 1])

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# <AxesSubplot: title={'center': 'XGBClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %% [markdown]
# ## ROC Curve

# %% [markdown]
# Imagine we improve our f1 score to 99%, how do we know that it is actually better? Confusion matrix could help but instead of comparing the percentage of right prediction in each class between two models, is there an easier way to compare to the performance of two models? That is when ROC AUC would be helpful.
#
# A ROCAUC plot allows the user to visualize the tradeoff between the classifier’s sensitivity and specificity. A ROC curve displays the true positive rate on the Y axis and the false positive rate on the X axis.

# %%
visualizer = ROCAUC(model, classes=[0, 1])

visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()
# Out:
# <AxesSubplot: title={'center': 'ROC Curves for XGBClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# # Explain Model

# %%
pip install opencv-python==4.5.5.64
# Out:
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 471.2 kB/s eta 0:00:0000:0100:04
# Requirement already satisfied: numpy>=1.14.5 in /home/ubuntu/anaconda3/envs/mlflow_thao/lib/python3.8/site-packages (from opencv-python==4.5.5.64) (1.22.4)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.7.0.72
#     Uninstalling opencv-python-4.7.0.72:
#       Successfully uninstalled opencv-python-4.7.0.72
# Successfully installed opencv-python-4.5.5.64
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap

explainer = shap.Explainer(model)
shap_values = explainer(X_train)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# ## SHAP Waterfall Plot

# %% [markdown]
# Visualize the first prediction’s explanation:

# %%
instance = 0

# %%
shap.plots.waterfall(shap_values[instance])

# %% [markdown]
# - The blue bar shows how much a particular feature decreases the value of the prediction.
# - The red bar shows how much a particular feature increases the value of the prediction.
# - Negative values imply probabilities of less than 0.5 that an employee leaves the company in 2 years.

# %% [markdown]
# ## SHAP Bar Plot

# %% [markdown]
# We can also get a global feature importance plot using the SHAP bar plot.

# %%
shap.plots.bar(shap_values)
